# %% [markdown]
# # 0_ライブラリのインポート

# %%
import pandas as pd         
import numpy as np
import matplotlib.pyplot as plt                                          
import matplotlib.figure as figure                                             
import seaborn as sns   #図用
import altair as alt     #図用
from ipywidgets import interact, Select, interactive_output, HBox  #インタラクティブな入力
from mpl_toolkits.mplot3d.axes3d import Axes3D  #3D図を扱う
import japanize_matplotlib
import warnings
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows',100)   #表データを何行まで表示するか

# %%
df = pd.read_csv('生データ\PubChem_compound_text_ester.csv')
# Out:
# C:\Users\706028\AppData\Local\Temp\ipykernel_23648\4224553967.py:1: DtypeWarning: Columns (32,33,35,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('生データ\PubChem_compound_text_ester.csv')

# %%
df.columns
# Out:
# Index(['cid', 'cmpdname', 'cmpdsynonym', 'mw', 'mf', 'polararea', 'complexity',
#        'xlogp', 'heavycnt', 'hbonddonor', 'hbondacc', 'rotbonds', 'inchi',
#        'isosmiles', 'canonicalsmiles', 'inchikey', 'iupacname', 'exactmass',
#        'monoisotopicmass', 'charge', 'covalentunitcnt', 'isotopeatomcnt',
#        'totalatomstereocnt', 'definedatomstereocnt', 'undefinedatomstereocnt',
#        'totalbondstereocnt', 'definedbondstereocnt', 'undefinedbondstereocnt',
#        'pclidcnt', 'gpidcnt', 'gpfamilycnt', 'neighbortype', 'meshheadings',
#        'annothits', 'annothitcnt', 'aids', 'cidcdate', 'sidsrcname', 'depcatg',
#        'annotation'],
#       dtype='object')

# %%
df1 = df[(~df['canonicalsmiles'].str.contains('N'))&(~df['canonicalsmiles'].str.contains('S'))&(~df['canonicalsmiles'].str.contains('P'))]
df1
# Out:
#               cid                                           cmpdname  \
# 0            2969                                      Decanoic acid
# 1            2345                                    Benzyl Benzoate
# 5            5541                                          Triacetin
# 6            4947                                     Propyl gallate
# 9            8434                                       Ethylparaben
# ...           ...                                                ...
# 170946  165429850  (1R,5S,6S)-rel-5-(1-Ethylpropoxy)-7-oxabicyclo...
# 170993   90473101  3,3a,7a,9b-Tetrahydro-3-(1-hydroxyethyl)-2-oxo...
# 171006  129893414  Tert-butyl 4-[(2-formyl-4-methylphenoxy)methyl...
# 171078  129894459  (1-methylcyclohexyl) (1S,4S)-bicyclo[2.2.1]hep...
# 171090  126968985  methyl (3S,4S,5R,6R)-3,4,5-triacetyloxy-6-meth...
#
#                                               cmpdsynonym      mw         mf  \
# ...

# %%
df1['canonicalsmiles']
# Out:
# 0                                          CCCCCCCCCC(=O)O
# 1                          C1=CC=C(C=C1)COC(=O)C2=CC=CC=C2
# 5                               CC(=O)OCC(COC(=O)C)OC(=O)C
# 6                            CCCOC(=O)C1=CC(=C(C(=C1)O)O)O
# 9                                   CCOC(=O)C1=CC=C(C=C1)O
#                                 ...
# 170946                       CCC(CC)OC1C=C(CC2C1O2)C(=O)OC
# 170993        CC(C1C2C3(C=CC4C3C(O2)OC(C4C(=O)OC)O)OC1=O)O
# 171006    CC1=CC(=C(C=C1)OCC2=CC=C(C=C2)C(=O)OC(C)(C)C)C=O
# 171078                       CC1(CCCCC1)OC(=O)C2CC3CC2C=C3
# 171090        CC(=O)OC1C(C(OC(C1OC(=O)C)OC)C(=O)OC)OC(=O)C
# Name: canonicalsmiles, Length: 39979, dtype: object
